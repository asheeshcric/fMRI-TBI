# %%
from nilearn.plotting import plot_anat, plot_img, plot_stat_map

# %%
img_loc = "/data/fmri/data/sub-tbi007/sub-tbi007.preproc/2back.r01.scale.nii.gz"

# %%
from nilearn import image

# %%
img = image.load_img(img_loc)

# %%
img.shape
# Out:
# (57, 68, 49, 135)

# %%
first_rsn = image.index_img(img, 0)
first_rsn.shape
# Out:
# (57, 68, 49)

# %%
plot_img(first_rsn)

# %%
plot_anat(first_rsn)

# %%
from nilearn.image import mean_img

# %%
mean = mean_img(img)
mean.shape
# Out:
# (57, 68, 49)

# %%
mean

# %%
plot_anat(mean)
